# %%
import jourtools as jrtl  # импортируем функции из файла "jourtools.py"
import json
from datetime import date
import os

# %%
field = jrtl.default_dict()

# %%
jrtl.save_state(field)

# %%
with open("groupe.txt", "r", encoding="utf-8") as f:
            json.load(f)

# %%
jrtl.read_state()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 read_state()
#
# File ~\Documents\Omelchenko\38is\journal\jourtools.py:66, in read_state()
#      64 try:
#      65     with open("groupe.txt", "r", encoding="utf-8") as f:
# ---> 66         return json.load(f)
#      67 except FileNotFoundError:
#      68     print("Файл не найден!")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)    291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 4 column 1 (char 1069)

# %% [raw]
# def display_student_list():
#     check_list = []
#     count = 1
#     for k, v in field.items():
#         check_list.append((count, k))
#         count += 1
#     for i in check_list:
#         print(i[0], i[1])

# %% [raw]
# def student_choice(number: int, field: dict) -> str:
#     check_list = []
#     count = 1
#     for k, v in field.items():
#         check_list.append((count, k))
#         count += 1
#     for i in check_list:
#         if i[0] == number:
#             return i[1]

# %%
student_choice(teacher_action(field), field)

# %%
tch = teacher_action

# %%
while True:
    num = int(input("1. Для изменения журнала\n"
    "2. Для сохранения файла\n"
    "3. Для чтения\n"
    "4. Для выхода\n"))
    match num:
        case 1:
            k = int(input("1. Для внесения в список опаздавшего\n"
            "2. Поставить оценку\n"))
            match k:
                case 1:
                    student = student_choice(tch(field), field)
                    presense_set(field, student)
                case 2:
                    mark = input("Введите имя и оценку через пробел (Имя 5):\n").split()
                    field[mark[0]]["mark"] = mark[1]
        case 2:
            save_state(field)
        case 3:
            name = input("Введите имя ученика, чтобы посмотреть его посещение и оценку: \n")
            data = read_states(field, str(current_date))
            print(data[name])
        case 4:
            break

# %%
default_list()
